# %% [markdown]
# ![grid.png](attachment:8150f6af-ba9d-4718-a530-25b109f15b8a.png)

# %%
import cv2 
import numpy as np

# Load image
image = cv2.imread('grid.png')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
blurred = cv2.GaussianBlur(gray, (5, 5), 0)

# Edge detection
edges = cv2.Canny(blurred, 50, 150, apertureSize=3)

# Line detection using Probabilistic Hough Transform
lines = cv2.HoughLinesP(edges, 1, np.pi/180, 100, minLineLength=100, maxLineGap=10)

# Create a blank image to draw lines
line_image = np.zeros_like(image)

# Draw the lines
for line in lines:
    x1, y1, x2, y2 = line[0]
    cv2.line(line_image, (x1, y1), (x2, y2), (0, 255, 0), 2)

# Show result
cv2.imshow("Detected Lines", line_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[5], line 6
#       4 # Load image
#       5 image = cv2.imread('grid.png')
# ----> 6 gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#       7 blurred = cv2.GaussianBlur(gray, (5, 5), 0)
#       9 # Edge detection
#
# error: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:196: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
import cv2
print(cv2.__version__)
# Out:
# 4.10.0
